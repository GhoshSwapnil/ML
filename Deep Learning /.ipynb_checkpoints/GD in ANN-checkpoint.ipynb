# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('../KNN/dataset/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df[['Age','EstimatedSalary','Purchased']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 2)

# %% [markdown]
# ## Stochastic GD

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model= Sequential()

model.add(Dense(10,activation='relu',input_dim=2))# Hidden layer 1 # 10 percepton with each activation function relu 
model.add(Dense(10,activation='relu'))# Hidden layer 2 # 10 percepton with each activation function relu 
model.add(Dense(1,activation='sigmoid'))# Hidden layer 3 # 1 percepton with  activation function sigmoid
# Out:
# 2022-10-26 13:56:41.115411: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary() # Trainable params: 151 # (2*10+ 10)+ (10*10+ 10)+ (10*1+ 1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=500,batch_size=1,validation_split=0.2) #stochastic GD 
#print(time.time() - start)
# Out:
# Epoch 1/500
# 320/320 [==============================] - 2s 6ms/step - loss: 0.5204 - accuracy: 0.8281 - val_loss: 0.5910 - val_accuracy: 0.7250
# Epoch 2/500
# 320/320 [==============================] - 2s 6ms/step - loss: 0.3467 - accuracy: 0.8594 - val_loss: 0.4770 - val_accuracy: 0.7500
# Epoch 3/500
# 320/320 [==============================] - 1s 5ms/step - loss: 0.3006 - accuracy: 0.8687 - val_loss: 0.3993 - val_accuracy: 0.8625
# Epoch 4/500
# 320/320 [==============================] - 1s 4ms/step - loss: 0.2919 - accuracy: 0.8656 - val_loss: 0.3613 - val_accuracy: 0.9125
# Epoch 5/500
# 320/320 [==============================] - 1s 5ms/step - loss: 0.2887 - accuracy: 0.8594 - val_loss: 0.3445 - val_accuracy: 0.9000
# Epoch 6/500
# 320/320 [==============================] - 1s 4ms/step - loss: 0.2907 - accuracy: 0.8594 - val_loss: 0.3099 - val_accuracy: 0.9125
# Epoch 7/500
# ...

# %%
history.history['accuracy']
# Out:
# [0.768750011920929,
#  0.7718750238418579,
#  0.7749999761581421,
#  0.765625,
#  0.7749999761581421,
#  0.7718750238418579,
#  0.7718750238418579,
#  0.768750011920929,
#  0.768750011920929,
#  0.7718750238418579]

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss']) # loss vs epochs

# %% [markdown]
# ##  Batch DC

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=250,validation_split=0.2) # batch GD 
#print(time.time() - start)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 350ms/step - loss: 0.6124 - accuracy: 0.7688 - val_loss: 0.7565 - val_accuracy: 0.4250
# Epoch 2/10
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6030 - accuracy: 0.7719 - val_loss: 0.7572 - val_accuracy: 0.4375
# Epoch 3/10
# 2/2 [==============================] - 0s 121ms/step - loss: 0.5958 - accuracy: 0.7750 - val_loss: 0.7570 - val_accuracy: 0.4375
# Epoch 4/10
# 2/2 [==============================] - 0s 146ms/step - loss: 0.5900 - accuracy: 0.7656 - val_loss: 0.7567 - val_accuracy: 0.4250
# Epoch 5/10
# 2/2 [==============================] - 0s 132ms/step - loss: 0.5850 - accuracy: 0.7750 - val_loss: 0.7567 - val_accuracy: 0.4250
# Epoch 6/10
# 2/2 [==============================] - 0s 107ms/step - loss: 0.5802 - accuracy: 0.7719 - val_loss: 0.7576 - val_accuracy: 0.4250
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
